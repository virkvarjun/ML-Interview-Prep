# %% [markdown]
# # Neural Networks: Forward and Backward Pass
#
# Neural Networks from scratch with numpy first, then pytorch.

# %%
# XOR Problem (NumPy Implementation)

import numpy as np 
np.random.seed(42) 

# Data Generation 
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=float) 
y = np.array([0, 1, 1, 0]) # (N, ) integer labels 

# Sizes: N examples, D features, H hidden, C classes 
N, D = X.shape 
H = 8 
C = 2   # classes: 0 or 1 

# One-hot: (N, ) -> (N, C)
y_onehot = np.zeros((N, C)) 
y_onehot[np.arange(N), y] = 1 

# Parameters 
W1 = np.random.randn(D, H) * 0.5 
b1 = np.zeros((1, H)) 
W2 = np.random.randn(H, C) * 0.5 
b2 = np.zeros((1, C))  
 
lr = 0.5 

def relu(Z): 
    return np.maximum(0, Z) 
def softmax(Z): 
    Z = Z - Z.max(axis=1, keepdims=True) 
    e = np.exp(Z) 
    return e / e.sum(axis=1, keepdims=True) 

# Forward Pass 

# Backward Pass 

# Update Weights 

# Loss Calculation 

# Training Loop 

# Prediction
